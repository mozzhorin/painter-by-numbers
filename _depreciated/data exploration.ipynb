# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
info = pd.read_csv('all_data_info.csv')

# %%
top10 = info.groupby('artist').count().sort_values(by='title', ascending=False).head(10)

# %%
top10.index[0]
# Out:
# 'Ivan Shishkin'

# %%
picasso3 = info[(info['artist']=='Pablo Picasso') & info['in_train'] & info['new_filename'].str.startswith('3')]

# %%
picasso3.head()
# Out:
#              artist  date               genre  pixelsx  pixelsy  size_bytes  \
# 5924  Pablo Picasso  1906      genre painting   1734.0   2464.0    888133.0
# 6298  Pablo Picasso  1906  nude painting (nu)   1793.0   2275.0    708621.0
# 6785  Pablo Picasso  1895            portrait   1573.0   2454.0    614828.0
# 7020  Pablo Picasso  1905      genre painting   1535.0   2447.0    544429.0
# 9370  Pablo Picasso  1901      genre painting   1436.0   2124.0    451092.0
#
#        source               style                            title  \
# 5924  wikiart       Expressionism                        The Harem
# 6298  wikiart       Expressionism               Bust of nude woman
# 6785  wikiart             Realism                The barefoot girl
# 7020  wikiart           Symbolism                 Girl on the ball
# 9370  wikiart  Post-Impressionism  The mother leading two children
#
#         artist_group  in_train new_filename
# 5924  train_and_test      True    37299.jpg
# ...

# %%
from IPython.display import Image

# %%
#train_dir = '/home/mo/Downloads/painters/train_3/'
train_dir = '/media/mo/My Passport/painters/train/'
for i in range(10):
    fn = train_dir + picasso3['new_filename'].iloc[i]
    Image(filename=fn)

# %%
Image(filename=str(train_dir + picasso3['new_filename'].iloc[30]))

# %%
info.describe()
# Out:
#              pixelsx        pixelsy    size_bytes
# count  103250.000000  103250.000000  1.032500e+05
# mean      960.808097     984.089976  3.883235e+05
# std       596.270314     625.139336  8.784776e+05
# min       200.000000     162.000000  3.516000e+03
# 25%       581.000000     599.000000  9.438625e+04
# 50%       800.000000     800.000000  1.676700e+05
# 75%      1102.000000    1097.000000  3.401280e+05
# max     25528.000000    9541.000000  3.244314e+07

# %%
pica
